# %% [markdown]
# # Munging data into proper formats and usable types (Part 2):

# %% [markdown]
# Since there are 12 columns, I will go through the df one column at a time and clean it up to a workable format that includes usable strings and a standardized format. Once complete, this data will be loaded into a database so this will need to be taken into consideration (i.e. cleaning to work up to 3NF structure db).
#
# Columns: ['botanical_name', 'common_name', 'family', 'plant_type', 'mature_size','sun_exposure', 'soil_type', 'soil_ph', 'bloom_time', 'flower_color','hardiness_zones', 'native_area']

# %%
#Read in file
file = 'Scrapped Plant Data.csv'
df = pd.read_csv(file, index_col=0)
# Out:
#                                          botanical_name  \
# 0                               Lagerstroemia x ‘Acoma’
# 1                                          Aeonium spp.
# 2                                         Aerangis spp.
# 3               African daisy, cape daisy, osteospermum
# 4          Afrocarpus gracilior or Podocarpus gracilior
# ...                                                 ...
# 1289  Euphorbia tithymaloides (formerly Pedilanthus ...
# 1290                 Hydrangea paniculata 'Zinfin Doll'
# 1291                       Pelargonium spp. and hybrids
# 1292                                        Zygopetalum
# 1293                             Zamioculcas zamiifolia
#
#                                             common_name         family  \
# 0                                    Acoma crape myrtle     Lythraceae
# 1                                               Aeonium   Crassulaceae
# 2                                      Aerangis orchids            NaN
# ...
